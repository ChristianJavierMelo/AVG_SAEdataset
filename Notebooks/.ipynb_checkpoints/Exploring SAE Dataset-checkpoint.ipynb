# %%
import numpy as np
import pandas as pd

pd.set_option('display.max_columns', None) #show all columns

import warnings
warnings.simplefilter('ignore') #to avoid warnings

# %% [markdown]
# ## Exploring the Data

# %%
sae=pd.read_csv('../data/sae_dataset.csv')
sae.head()
# Out:
#   VehicleMarketCode  VehicleNationalCode VehicleSegmentationGlobal  \
# 0                ES                29263                 Small LCV
# 1                ES                29263                 Small LCV
# 2                ES                29263                 Small LCV
# 3                ES                30020                         E
# 4                ES                30020                         E
#
#   VehicleModelIntlName Bodytype_Group Fuel_Group Transmission_Group  \
# 0                Combo      Panel van     Diesel             Manual
# 1                Combo      Panel van     Diesel             Manual
# 2                Combo      Panel van     Diesel             Manual
# 3                  607          Sedan     Diesel          Automated
# 4                  607          Sedan     Diesel          Automated
#
#   Drivetype_Group  VehicleKW  VehicleDoors  VehicleWheelBase  VehicleSeats  \
# 0             2WD         73           4.0            2716.0             2
# 1             2WD         73           4.0            2716.0             2
# 2             2WD         73           4.0            2716.0             2
# 3             2WD        150           4.0            2800.0             5
# 4             2WD        150           4.0            2800.0             5
#
#    VehicleGrossNewPrice VehicleProductionStart VehicleProductionEnd  \
# 0               19321.0               7/1/2004            12/1/2011
# 1               19321.0               7/1/2004            12/1/2011
# 2               19321.0               7/1/2004            12/1/2011
# 3               54250.0              12/1/2004             8/1/2012
# 4               54250.0              12/1/2004             8/1/2012
#
#   VehicleMakeIntlName SAEReporteddate  StockDays PostCode registration_date  \
# 0     OPEL / VAUXHALL        2/3/2020         12    28983          7/1/2008
# 1     OPEL / VAUXHALL        2/3/2020         86     8940         6/15/2010
# 2     OPEL / VAUXHALL        2/3/2020        279     8840          7/1/2005
# 3             PEUGEOT      10/12/2022         55    27002        10/15/2009
# 4             PEUGEOT        2/3/2020         75    18015          7/1/2006
#
#    Mileage  Price  oricpric  PriceChangeCount
# 0   238000   2990    2990.0               NaN
# 1    90000   4499    4499.0               NaN
# 2   210000   2490    2700.0               1.0
# 3   259000   6500    6500.0               NaN
# 4   155000   4900    7500.0               1.0

# %%
sae.shape
# Out:
# (192880, 24)

# %% [markdown]
# ### 1. Descriptive stats

# %% [markdown]
# In order to get a basic understanding of the dataset, I explore the null values & data type in each column:

# %%
sae.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192880 entries, 0 to 192879
# Data columns (total 24 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   VehicleMarketCode          192880 non-null  object
#  1   VehicleNationalCode        192880 non-null  int64
#  2   VehicleSegmentationGlobal  192880 non-null  object
#  3   VehicleModelIntlName       192880 non-null  object
#  4   Bodytype_Group             192880 non-null  object
#  5   Fuel_Group                 192880 non-null  object
#  6   Transmission_Group         192880 non-null  object
#  7   Drivetype_Group            192880 non-null  object
#  8   VehicleKW                  192880 non-null  int64
#  9   VehicleDoors               192859 non-null  float64
#  10  VehicleWheelBase           192834 non-null  float64
#  11  VehicleSeats               192880 non-null  int64
#  12  VehicleGrossNewPrice       192880 non-null  float64
#  13  VehicleProductionStart     192880 non-null  object
#  14  VehicleProductionEnd       192880 non-null  object
#  15  VehicleMakeIntlName        192880 non-null  object
#  16  SAEReporteddate            192880 non-null  object
#  17  StockDays                  192880 non-null  int64
#  18  PostCode                   192880 non-null  object
#  19  registration_date          192880 non-null  object
#  20  Mileage                    192880 non-null  int64
#  21  Price                      192880 non-null  int64
#  22  oricpric                   192684 non-null  float64
#  23  PriceChangeCount           73872 non-null   float64
# dtypes: float64(5), int64(6), object(13)
# memory usage: 35.3+ MB

# %%
sae.isna().sum()
# Out:
# VehicleMarketCode                 0
# VehicleNationalCode               0
# VehicleSegmentationGlobal         0
# VehicleModelIntlName              0
# Bodytype_Group                    0
# Fuel_Group                        0
# Transmission_Group                0
# Drivetype_Group                   0
# VehicleKW                         0
# VehicleDoors                     21
# VehicleWheelBase                 46
# VehicleSeats                      0
# VehicleGrossNewPrice              0
# VehicleProductionStart            0
# VehicleProductionEnd              0
# VehicleMakeIntlName               0
# SAEReporteddate                   0
# StockDays                         0
# PostCode                          0
# registration_date                 0
# Mileage                           0
# Price                             0
# oricpric                        196
# PriceChangeCount             119008
# dtype: int64

# %% [markdown]
# There are no relevant null values. Taking a look at the PriceChangeCount, null values could mean multiple values, so I can't just fill with 0 value.

# %% [markdown]
# ##### Taking a look at the data type, it would be advisable to make some changes in order to perform possible calculations with them
# * Natcode is the ID of AVG, so it should be an string instead of Integer
# * Fields related to date are strings instead of datetime. I will set as a date

# %%
sae['VehicleNationalCode']=sae['VehicleNationalCode'].astype('str')
sae['registration_date']=pd.to_datetime(sae['registration_date'], format='%m/%d/%Y')
sae['SAEReporteddate']=pd.to_datetime(sae['SAEReporteddate'], format='%m/%d/%Y')
sae['VehicleProductionStart']=pd.to_datetime(sae['VehicleProductionStart'], format='%m/%d/%Y')
sae['VehicleProductionEnd']=pd.to_datetime(sae['VehicleProductionEnd'], format='%m/%d/%Y', errors='coerce')

# %%
sae.dtypes
# Out:
# VehicleMarketCode                    object
# VehicleNationalCode                  object
# VehicleSegmentationGlobal            object
# VehicleModelIntlName                 object
# Bodytype_Group                       object
# Fuel_Group                           object
# Transmission_Group                   object
# Drivetype_Group                      object
# VehicleKW                             int64
# VehicleDoors                        float64
# VehicleWheelBase                    float64
# VehicleSeats                          int64
# VehicleGrossNewPrice                float64
# VehicleProductionStart       datetime64[ns]
# VehicleProductionEnd         datetime64[ns]
# VehicleMakeIntlName                  object
# SAEReporteddate              datetime64[ns]
# StockDays                             int64
# PostCode                             object
# registration_date            datetime64[ns]
# Mileage                               int64
# Price                                 int64
# oricpric                            float64
# PriceChangeCount                    float64
# dtype: object

# %% [markdown]
# ### 2. Exploring the data in detail

# %% [markdown]
# #### 2.1 Categorical data
# I'm going to review the most relevant categorical columns from my point of view

# %%
sae.select_dtypes(exclude=['int64','float64'])
# Out:
#        VehicleMarketCode VehicleNationalCode VehicleSegmentationGlobal  \
# 0                     ES               29263                 Small LCV
# 1                     ES               29263                 Small LCV
# 2                     ES               29263                 Small LCV
# 3                     ES               30020                         E
# 4                     ES               30020                         E
# ...                  ...                 ...                       ...
# 192875                PT              934825                         B
# 192876                PT              934825                         B
# 192877                PT              934825                         B
# 192878                PT              934825                         B
# 192879                PT              934964                         B
#
#        VehicleModelIntlName Bodytype_Group Fuel_Group Transmission_Group  \
# 0                     Combo      Panel van     Diesel             Manual
# 1                     Combo      Panel van     Diesel             Manual
# 2                     Combo      Panel van     Diesel             Manual
# 3                       607          Sedan     Diesel          Automated
# 4                       607          Sedan     Diesel          Automated
# ...                     ...            ...        ...                ...
# 192875                Micra      Hatchback     Petrol             Manual
# 192876                Micra      Hatchback     Petrol             Manual
# 192877                Micra      Hatchback     Petrol             Manual
# 192878                Micra      Hatchback     Petrol             Manual
# 192879                 Clio      Hatchback     Petrol             Manual
#
#        Drivetype_Group VehicleProductionStart VehicleProductionEnd  \
# 0                  2WD             2004-07-01           2011-12-01
# 1                  2WD             2004-07-01           2011-12-01
# 2                  2WD             2004-07-01           2011-12-01
# 3                  2WD             2004-12-01           2012-08-01
# 4                  2WD             2004-12-01           2012-08-01
# ...                ...                    ...                  ...
# 192875             2WD             2022-02-01                  NaT
# 192876             2WD             2022-02-01                  NaT
# 192877             2WD             2022-02-01                  NaT
# 192878             2WD             2022-02-01                  NaT
# 192879             2WD             2022-04-01                  NaT
#
#        VehicleMakeIntlName SAEReporteddate PostCode registration_date
# 0          OPEL / VAUXHALL      2020-02-03    28983        2008-07-01
# 1          OPEL / VAUXHALL      2020-02-03     8940        2010-06-15
# 2          OPEL / VAUXHALL      2020-02-03     8840        2005-07-01
# 3                  PEUGEOT      2022-10-12    27002        2009-10-15
# 4                  PEUGEOT      2020-02-03    18015        2006-07-01
# ...                    ...             ...      ...               ...
# 192875              NISSAN      2022-10-12     1000        2022-05-15
# 192876              NISSAN      2022-10-12     3515        2022-04-15
# 192877              NISSAN      2022-10-12     8200        2022-03-15
# 192878              NISSAN      2022-10-12     2830        2022-05-15
# 192879             RENAULT      2022-10-12     2420        2022-05-15
#
# [192880 rows x 14 columns]

# %%
sae.VehicleMarketCode.value_counts()
# Out:
# ES    176407
# PT     16473
# Name: VehicleMarketCode, dtype: int64

# %%
sae.VehicleMakeIntlName.value_counts()
# Out:
# RENAULT       23370
# PEUGEOT       17070
# SEAT          15328
# BMW           14385
# FORD (EUR)    14078
#               ...
# PIAGGIO           2
# MPM MOTORS        1
# BORGWARD          1
# MORGAN            1
# SAAB              1
# Name: VehicleMakeIntlName, Length: 61, dtype: int64

# %%
sae.VehicleNationalCode.value_counts()
# Out:
# 74488     852
# 83098     652
# 80819     569
# 68495     567
# 56630     541
#          ...
# 56877       1
# 56901       1
# 56903       1
# 83619       1
# 934964      1
# Name: VehicleNationalCode, Length: 15867, dtype: int64

# %% [markdown]
# Based on AVG ID, I see that the most repeated vehicle in the Dataset is the following:

# %%
sae[sae.VehicleNationalCode=='74488'].head()
# Out:
#        VehicleMarketCode VehicleNationalCode VehicleSegmentationGlobal  \
# 116852                ES               74488                     B SUV
# 116853                ES               74488                     B SUV
# 116854                ES               74488                     B SUV
# 116855                ES               74488                     B SUV
# 116856                ES               74488                     B SUV
#
#        VehicleModelIntlName Bodytype_Group Fuel_Group Transmission_Group  \
# 116852                 C-HR      Coupe SUV     Hybrid          Automated
# 116853                 C-HR      Coupe SUV     Hybrid          Automated
# 116854                 C-HR      Coupe SUV     Hybrid          Automated
# 116855                 C-HR      Coupe SUV     Hybrid          Automated
# 116856                 C-HR      Coupe SUV     Hybrid          Automated
#
#        Drivetype_Group  VehicleKW  VehicleDoors  VehicleWheelBase  \
# 116852             2WD         90           5.0            2640.0
# 116853             2WD         90           5.0            2640.0
# 116854             2WD         90           5.0            2640.0
# 116855             2WD         90           5.0            2640.0
# 116856             2WD         90           5.0            2640.0
#
#         VehicleSeats  VehicleGrossNewPrice VehicleProductionStart  \
# 116852             5               28990.0             2016-12-01
# 116853             5               28990.0             2016-12-01
# 116854             5               28990.0             2016-12-01
# 116855             5               28990.0             2016-12-01
# 116856             5               28990.0             2016-12-01
#
#        VehicleProductionEnd VehicleMakeIntlName SAEReporteddate  StockDays  \
# 116852           2019-10-01              TOYOTA      2020-02-03         29
# 116853           2019-10-01              TOYOTA      2020-02-03         17
# 116854           2019-10-01              TOYOTA      2022-10-12          5
# 116855           2019-10-01              TOYOTA      2022-10-12          2
# 116856           2019-10-01              TOYOTA      2020-02-03         16
#
#        PostCode registration_date  Mileage  Price  oricpric  PriceChangeCount
# 116852    29004        2018-07-01    38600  21990   21990.0               NaN
# 116853    25194        2019-07-01     3720  22200   22200.0               NaN
# 116854    46014        2019-09-15    47467  25750   25750.0               NaN
# 116855    33600        2018-07-01    36000  25900   25900.0               NaN
# 116856    46015        2019-07-01    11893  23900   23900.0               NaN

# %% [markdown]
# ##### Thinking about date fields

# %% [markdown]
# As Carsten told me about Dataset, SAEReportedDate was the date the snippet was taken from. I'd like to check how many reports are on this dataset

# %%
sae.SAEReporteddate.value_counts()
# Out:
# 2020-02-03    118597
# 2022-10-12     74283
# Name: SAEReporteddate, dtype: int64

# %% [markdown]
# There are two reports in this dataset. Perhaps it is interesting to take it into account separately, since there have been external circumstances that have been able to alter the values (e.g. the global pandemic)

# %%
sae2020=sae[sae.SAEReporteddate=='2020-02-03']
sae2022=sae[sae.SAEReporteddate=='2022-10-12']

# %% [markdown]
# It may be interesting to create a new column with the **"age of the vehicle"** according to its **registration_date** until the respective **SAEReportedDate**

# %%
sae['AgeOfVeh']=(sae['SAEReporteddate'] - sae['registration_date'])/np.timedelta64(1,'Y')

# %%
sae=sae.round(2)

# %%
sae.AgeOfVeh.value_counts()
# Out:
# 1.59     11937
# 3.59     11563
# 4.59     11410
# 0.59     10333
# 2.59     10025
#          ...
# 15.24        1
# 6.76         1
# 6.51         1
# 12.81        1
# 13.56        1
# Name: AgeOfVeh, Length: 457, dtype: int64

# %%
sae.pivot_table(index=['VehicleMarketCode'], columns=['SAEReporteddate'], aggfunc='mean')
# Out:
#                     AgeOfVeh                  Mileage                 \
# SAEReporteddate   2020-02-03 2022-10-12    2020-02-03     2022-10-12
# VehicleMarketCode
# ES                  3.864124   5.194400  68701.517088   86884.679629
# PT                  3.919954   5.329197  84081.331357  101563.574058
#
#                           Price               PriceChangeCount             \
# SAEReporteddate      2020-02-03    2022-10-12       2020-02-03 2022-10-12
# VehicleMarketCode
# ES                 16832.019462  21377.179025         1.938592   1.850572
# PT                 15039.743952  18750.737097         1.812662   1.616865
#
#                    StockDays            VehicleDoors             \
# SAEReporteddate   2020-02-03 2022-10-12   2020-02-03 2022-10-12
# VehicleMarketCode
# ES                 78.239822  72.838018     4.685257   4.717294
# PT                 86.357922  91.244373     4.811670   4.821415
#
#                   VehicleGrossNewPrice                VehicleKW              \
# SAEReporteddate             2020-02-03    2022-10-12 2020-02-03  2022-10-12
# VehicleMarketCode
# ES                        29770.109100  32076.639504  98.361067  103.565774
# PT                        25132.758302  27361.055839  77.319616   85.251834
#
#                   VehicleSeats            VehicleWheelBase               \
# SAEReporteddate     2020-02-03 2022-10-12       2020-02-03   2022-10-12
# VehicleMarketCode
# ES                    4.911097    4.88933      2673.098723  2675.497191
# PT                    4.918287    4.93471      2624.070090  2637.866683
#
#                        oricpric
# SAEReporteddate      2020-02-03    2022-10-12
# VehicleMarketCode
# ES                 17186.069278  21664.264558
# PT                 15339.980313  18777.759483

# %% [markdown]
# ##### 2.2 Numerical data
# In order to look at multiple descriptive statistics at once, I use the describe function. This will show the count, mean, standard deviation, minimum, 25th percentile, median (50th percentile), 75th percentile, and the maximum.

# %%
sae.describe().T
# Out:
#                          count          mean           std      min       25%  \
# VehicleKW             192880.0     98.682186     47.152377     4.00     73.00
# VehicleDoors          192859.0      4.707465      0.696083     2.00      5.00
# VehicleWheelBase      192834.0   2670.309411    180.183084  1686.00   2580.00
# VehicleSeats          192880.0      4.904920      0.725362     1.00      5.00
# VehicleGrossNewPrice  192880.0  30259.096283  18962.733322  7140.00  20450.00
# StockDays             192880.0     77.281688     75.502168     0.00     19.00
# Mileage               192880.0  76988.615009  57069.621542     1.00  27780.75
# Price                 192880.0  18394.630418  13789.559508  1390.00  10990.00
# oricpric              192684.0  18706.690836  16686.700415    -1.00  11100.00
# PriceChangeCount       73872.0      1.889173      1.773183     1.00      1.00
# AgeOfVeh              192880.0      4.384507      2.821886     0.05      2.28
#
#                            50%        75%         max
# VehicleKW                88.00     110.00      586.00
# VehicleDoors              5.00       5.00        6.00
# VehicleWheelBase       2648.00    2728.00     4522.00
# VehicleSeats              5.00       5.00        9.00
# VehicleGrossNewPrice  25850.00   33390.00   407250.00
# StockDays                53.00     110.00      401.00
# Mileage               69000.00  113727.75   350000.00
# Price                 15400.00   21028.00   415900.00
# oricpric              15500.00   21500.00  2390000.00
# PriceChangeCount          1.00       2.00       95.00
# AgeOfVeh                  4.24       5.80       15.99

# %% [markdown]
# The two main measures of central tendency are the mean and the median (50th percentile). Those variables that are close in mean and median value, means the data is symmetrically distributed around the mean.
#
# On most important fields considered by me for the dataset, I'm seeing the mean is greater than the median, so data is right skewed. This means there are a few outliers that influence the mean.

# %% [markdown]
# Quick look to oricpric column where the max value is highest than VehicleGrossNewPrice

# %%
sae[(sae.oricpric==2390000)]
# Out:
#        VehicleMarketCode VehicleNationalCode VehicleSegmentationGlobal  \
# 165374                ES               85177                     C SUV
#
#        VehicleModelIntlName Bodytype_Group Fuel_Group Transmission_Group  \
# 165374             Sportage     Closed SUV     Diesel             Manual
#
#        Drivetype_Group  VehicleKW  VehicleDoors  VehicleWheelBase  \
# 165374             2WD         85           5.0            2670.0
#
#         VehicleSeats  VehicleGrossNewPrice VehicleProductionStart  \
# 165374             5               32200.0             2019-05-01
#
#        VehicleProductionEnd VehicleMakeIntlName SAEReporteddate  StockDays  \
# 165374           2020-10-01                 KIA      2022-10-12        210
#
#        PostCode registration_date  Mileage  Price   oricpric  \
# 165374     8201        2020-01-15    22500  26900  2390000.0
#
#         PriceChangeCount  AgeOfVeh
# 165374               3.0      2.74

# %% [markdown]
# ##### Could be some typing errors in oricpric column that could be fixed before analysis. Lets take a look from highest to lowest sort values

# %%
sae.sort_values(by=['oricpric'], ascending=False)
# Out:
#        VehicleMarketCode VehicleNationalCode VehicleSegmentationGlobal  \
# 165374                ES               85177                     C SUV
# 104344                ES               72203                 Large LCV
# 170239                ES               89414                         B
# 89277                 ES               69004                     Sport
# 89274                 ES               69004                     Sport
# ...                  ...                 ...                       ...
# 174971                ES               93204                     C SUV
# 175190                ES               93519                         C
# 175252                ES               93728                         B
# 175747                ES               93917                         C
# 175924                ES               94315                         C
#
#        VehicleModelIntlName Bodytype_Group      Fuel_Group Transmission_Group  \
# 165374             Sportage     Closed SUV          Diesel             Manual
# 104344             Boxer 35      Panel van          Diesel             Manual
# 170239                 Clio      Hatchback          Hybrid          Automated
# 89277             Aventador         Cabrio          Petrol          Automated
# 89274             Aventador         Cabrio          Petrol          Automated
# ...                     ...            ...             ...                ...
# 174971            Formentor     Closed SUV  Plug-in Hybrid          Automated
# 175190            Megane IV      Hatchback  Plug-in Hybrid          Automated
# 175252                Ibiza      Hatchback             CNG             Manual
# 175747                  308      Hatchback          Diesel          Automated
# 175924                 Leon      Hatchback             CNG             Manual
#
#        Drivetype_Group  VehicleKW  VehicleDoors  VehicleWheelBase  \
# 165374             2WD         85           5.0            2670.0
# 104344             2WD         96           4.0            4035.0
# 170239             2WD        103           5.0            2583.0
# 89277              4WD        515           2.0            2700.0
# 89274              4WD        515           2.0            2700.0
# ...                ...        ...           ...               ...
# 174971             2WD        180           5.0            2680.0
# 175190             2WD        117           5.0            2670.0
# 175252             2WD         66           5.0            2564.0
# 175747             2WD         96           5.0            2675.0
# 175924             2WD         96           5.0            2686.0
#
#         VehicleSeats  VehicleGrossNewPrice VehicleProductionStart  \
# 165374             5               32200.0             2019-05-01
# 104344             3               35950.0             2016-05-01
# 170239             5               23460.0             2020-06-01
# 89277              2              407250.0             2015-01-01
# 89274              2              407250.0             2015-01-01
# ...              ...                   ...                    ...
# 174971             5               48840.0             2021-03-01
# 175190             5               41425.0             2021-05-01
# 175252             5               21960.0             2021-06-01
# 175747             5               33680.0             2021-06-01
# 175924             5               27010.0             2021-08-01
#
#        VehicleProductionEnd VehicleMakeIntlName SAEReporteddate  StockDays  \
# 165374           2020-10-01                 KIA      2022-10-12        210
# 104344           2019-05-01             PEUGEOT      2022-10-12          5
# 170239           2022-01-01             RENAULT      2022-10-12        227
# 89277            2019-02-01         LAMBORGHINI      2020-02-03         56
# 89274            2019-02-01         LAMBORGHINI      2020-02-03        261
# ...                     ...                 ...             ...        ...
# 174971                  NaT               CUPRA      2022-10-12        148
# 175190           2022-04-01             RENAULT      2022-10-12        124
# 175252           2022-06-01                SEAT      2022-10-12        129
# 175747           2022-08-01             PEUGEOT      2022-10-12        131
# 175924           2022-05-01                SEAT      2022-10-12        148
#
#        PostCode registration_date  Mileage   Price   oricpric  \
# 165374     8201        2020-01-15    22500   26900  2390000.0
# 104344    46714        2019-07-01    75969   23499  2350000.0
# 170239    29600        2021-07-01    10400   20400  2070000.0
# 89277     28029        2018-08-15     1470  415900   415900.0
# 89274     28029        2017-04-15     3890  399900   399900.0
# ...         ...               ...      ...     ...        ...
# 174971     8023        2021-02-15    21453   44900        NaN
# 175190    39011        2021-09-15    17796   29990        NaN
# 175252     8720        2021-07-15    15741   16400        NaN
# 175747    28805        2021-06-15    25786   22490        NaN
# 175924     8023        2022-02-15      540   22900        NaN
#
#         PriceChangeCount  AgeOfVeh
# 165374               3.0      2.74
# 104344               1.0      3.28
# 170239               3.0      1.28
# 89277                NaN      1.47
# 89274                NaN      2.80
# ...                  ...       ...
# 174971               6.0      1.65
# 175190               4.0      1.07
# 175252               2.0      1.24
# 175747               3.0      1.33
# 175924               4.0      0.65
#
# [192880 rows x 25 columns]

# %%
sae['oricpric']=sae['oricpric'].replace(to_replace=2390000, value=23900)
sae['oricpric']=sae['oricpric'].replace(to_replace=2350000, value=23500)
sae['oricpric']=sae['oricpric'].replace(to_replace=2070000, value=20700)

# %% [markdown]
# Checking the "oricpric" column in ascending order, it's not possible to fix more data in this approximation.

# %%
sae.sort_values(by=['oricpric'], ascending=True)
# Out:
#        VehicleMarketCode VehicleNationalCode VehicleSegmentationGlobal  \
# 177519                PT               56530                         A
# 181620                PT               72456                     B SUV
# 176873                PT               53118                         C
# 179093                PT               64600                         C
# 180310                PT               68121                         C
# ...                  ...                 ...                       ...
# 174971                ES               93204                     C SUV
# 175190                ES               93519                         C
# 175252                ES               93728                         B
# 175747                ES               93917                         C
# 175924                ES               94315                         C
#
#         VehicleModelIntlName Bodytype_Group      Fuel_Group  \
# 177519                   i10      Hatchback          Petrol
# 181620             C4 Cactus     Closed SUV          Diesel
# 176873             Giulietta      Hatchback          Diesel
# 179093                  Leon      Hatchback          Diesel
# 180310  Megane III Grandtour   Stationwagon          Diesel
# ...                      ...            ...             ...
# 174971             Formentor     Closed SUV  Plug-in Hybrid
# 175190             Megane IV      Hatchback  Plug-in Hybrid
# 175252                 Ibiza      Hatchback             CNG
# 175747                   308      Hatchback          Diesel
# 175924                  Leon      Hatchback             CNG
#
#        Transmission_Group Drivetype_Group  VehicleKW  VehicleDoors  \
# 177519             Manual             2WD         62           5.0
# 181620             Manual             2WD         73           5.0
# 176873             Manual             2WD         77           5.0
# 179093             Manual             2WD        110           5.0
# 180310             Manual             2WD         81           5.0
# ...                   ...             ...        ...           ...
# 174971          Automated             2WD        180           5.0
# 175190          Automated             2WD        117           5.0
# 175252             Manual             2WD         66           5.0
# 175747          Automated             2WD         96           5.0
# 175924             Manual             2WD         96           5.0
#
#         VehicleWheelBase  VehicleSeats  VehicleGrossNewPrice  \
# 177519            2380.0             5               11200.0
# 181620            2595.0             5               24360.0
# 176873            2634.0             5               25600.0
# 179093            2634.0             5               32666.0
# 180310            2703.0             5               28180.0
# ...                  ...           ...                   ...
# 174971            2680.0             5               48840.0
# 175190            2670.0             5               41425.0
# 175252            2564.0             5               21960.0
# 175747            2675.0             5               33680.0
# 175924            2686.0             5               27010.0
#
#        VehicleProductionStart VehicleProductionEnd VehicleMakeIntlName  \
# 177519             2011-03-01           2012-11-01             HYUNDAI
# 181620             2014-11-01           2018-05-01             CITROEN
# 176873             2010-04-01           2013-03-01          ALFA ROMEO
# 179093             2013-01-01           2015-06-01                SEAT
# 180310             2013-10-01           2015-05-01             RENAULT
# ...                       ...                  ...                 ...
# 174971             2021-03-01                  NaT               CUPRA
# 175190             2021-05-01           2022-04-01             RENAULT
# 175252             2021-06-01           2022-06-01                SEAT
# 175747             2021-06-01           2022-08-01             PEUGEOT
# 175924             2021-08-01           2022-05-01                SEAT
#
#        SAEReporteddate  StockDays  PostCode registration_date  Mileage  Price  \
# 177519      2022-10-12         12  2705-906        2012-01-15    93576   7490
# 181620      2022-10-12        159  3780-621        2017-05-15    64012  16900
# 176873      2022-10-12        153  3780-621        2011-04-15    67021  12850
# 179093      2022-10-12        221  3780-621        2013-11-15   128275  16450
# 180310      2022-10-12        202  4785-625        2014-11-15   165326  11900
# ...                ...        ...       ...               ...      ...    ...
# 174971      2022-10-12        148      8023        2021-02-15    21453  44900
# 175190      2022-10-12        124     39011        2021-09-15    17796  29990
# 175252      2022-10-12        129      8720        2021-07-15    15741  16400
# 175747      2022-10-12        131     28805        2021-06-15    25786  22490
# 175924      2022-10-12        148      8023        2022-02-15      540  22900
#
#         oricpric  PriceChangeCount  AgeOfVeh
# 177519      -1.0               1.0     10.74
# 181620      -1.0               1.0      5.41
# 176873      -1.0               1.0     11.49
# 179093      -1.0               1.0      8.91
# 180310       0.0               1.0      7.91
# ...          ...               ...       ...
# 174971       NaN               6.0      1.65
# 175190       NaN               4.0      1.07
# 175252       NaN               2.0      1.24
# 175747       NaN               3.0      1.33
# 175924       NaN               4.0      0.65
#
# [192880 rows x 25 columns]

# %% [markdown]
# #### Save the dataset updated

# %%
sae.to_csv('../data/sae_dataset_updated.csv', index=False)
